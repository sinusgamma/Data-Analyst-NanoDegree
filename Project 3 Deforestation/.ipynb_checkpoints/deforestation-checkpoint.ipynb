# %% [markdown]
# # Project: Forest area change 1992-2015
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# About 30 percent of the land surface is covered by forest on Earth, but during the history, forest area was decreasing because of the population growth, agriculture, wood industry, and other effects. According to some estimation [link](https://www.nationalgeographic.com/environment/global-warming/deforestation/), the rainforests could completely vanish in a hundred year with the current rate of deforestation.
# Now I want to examine the changes in forest area during the 1992-2015 period. My goal is to find the countries, or group of countries, who lost the most forest, and other countries where the forest area even increased. I try to find some correlation with different population parameters as well.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
#
# ### The dataset
# Source of the data: https://www.gapminder.org/data/
#
# Data explanation:
#
# Forest area: dataframe: df_forest - Forest area in square km.
#
# Forest area ratio: dataframe: df_forest_ratio - Percent of land area.
#
# Agricultural land ratio: dataframe: df_agrtoland - Percent of land area.
#
# Agricultural land area: dataframe: df_agr_area - Agricultural land area calculated from df_agrtoland and df_area.
#
# Agriculture, value added: dataframe: df_agrtogdp - Percent of GDP
#
# GDP per capita growth: dataframe: df_gdpgr - GDP per capita growth annual percent.
#
# GDP per capita: dataframe: df_gdp_p - GDP divided by midyear population. (US$)
#
# Population density: dataframe: df_popd - Population density per square km.
#
# Population growth: dataframe: df_popg - Annual population growth rate.
#
# Total population: dataframe: df_pop_tot - Total population of the country.
#
# Country area: dataframe: df_area - Surface area in square km.

# %% [markdown]
# df_agr_area (agricultural area of a country) will be calculated after cleaning the data.
# Instead of one multiindex dataframe I used multiple dataframes. In this case with multiple dataframes it was more easy to comprehend the data.
#
# I added the datasets to a dictionary. Later I will use dataframe manipulations which are very easy to do with dictionary comprehension or looping trough a dictionary.
#
# / with df = pd.concat(df_dict).transpose() the dataframes could be convertd to a single dataframe

# %%
# load data
df_dict = {}
df_forest = pd.read_csv('Data/forest_area_sq_km.csv')
df_dict['forest_area'] = df_forest
df_forest_ratio = pd.read_csv('Data/forest_coverage_percent.csv')
df_dict['forest_ratio'] = df_forest_ratio
df_popt = pd.read_csv('Data/population_total.csv')
df_dict['population_total'] = df_popt
df_popg = pd.read_csv('Data/population_growth_annual_percent.csv')
df_dict['population_growth'] = df_popg
df_popd = pd.read_csv('Data/population_density_per_square_km.csv')
df_dict['population_density'] = df_popd
df_gdpgr = pd.read_csv('Data/gdp_per_capita_yearly_growth.csv')
df_dict['gdp_growth_pc'] = df_gdpgr
df_gdp_tot = pd.read_csv('Data/total_gdp_us_inflation_adjusted.csv')
df_dict['gdp_tot'] = df_gdp_tot
df_gdp_pc = pd.read_csv('Data/gdppercapita_us_inflation_adjusted.csv')
df_dict['gdp_pc'] = df_gdp_pc
df_agrtoland = pd.read_csv('Data/agricultural_land_percent_of_land_area.csv')
df_dict['agricultural_land_ratio'] = df_agrtoland
df_agrtogdp = pd.read_csv('Data/agriculture_percent_of_gdp.csv')
df_dict['agricultural_gdp_ratio'] = df_agrtogdp
df_area = pd.read_csv('Data/surface_area_sq_km.csv')
df_dict['surface_area'] = df_area
df_dict.keys()
# Out:
# dict_keys(['forest_area', 'forest_ratio', 'population_total', 'population_growth', 'population_density', 'gdp_growth_pc', 'gdp_tot', 'gdp_pc', 'agricultural_land_ratio', 'agricultural_gdp_ratio', 'surface_area'])

# %%
def shape_data(df_toshape):
    """
    This function transforms the country column (geo) to the dataframe index, 
    drops the dates wich aren't in the range of the examination.
    Inplace is used to alter the original dataframe, but it is returned as well.
    Args:
        df_toshape (dataframe): dataframe to shape
    Return:
        the shaped dataframe
    """
    if 'geo' in df_toshape.columns:
        df_toshape.set_index('geo', inplace=True)
        early_dates = [x.astype(str) for x in list(df_toshape.columns.values.astype(int)) if x < 1992]
        late_dates = [x.astype(str) for x in list(df_toshape.columns.values.astype(int)) if x > 2015]
        drop_dates = early_dates + late_dates
        df_toshape.drop(drop_dates, axis=1, inplace=True)
        return df_toshape
    else:
        print("Column name 'geo' doesn't exist, returned the same dataframe.")
        return df_toshape

# %% [markdown]
# ### Examination of the dataset

# %%
#df_forest = shape_data(df_forest)
#forest_1992 = df_forest['1992'].sort_values(ascending=False)
#forest_1992 = pd.DataFrame([forest_1992]).transpose()
#forest_1992 = forest_1992.rename(columns={"1992": "area"})
#world_total = forest_1992.sum()['area']
#forest_1992['word_pct'] = (forest_1992 / world_total)*100
#forest_1992['cum_word_pct'] = forest_1992.cumsum()['word_pct']
#forest_1992.head()

# %% [markdown]
# First I check the shape of the datasets. Unfortunatelly they have different shapes.

# %%
for k, v in df_dict.items():
    print(k + ": ")
    print(v.shape)
# Out:
# forest_area:
# (193, 27)
# forest_ratio:
# (192, 27)
# population_total:
# (195, 220)
# population_growth:
# (194, 59)
# population_density:
# (195, 152)
# gdp_growth_pc:
# (194, 220)
# gdp_tot:
# (190, 59)
# gdp_pc:
# (190, 59)
# agricultural_land_ratio:
# (192, 56)
# agricultural_gdp_ratio:
# (189, 59)
# surface_area:
# (194, 58)

# %% [markdown]
# The dataframes have very different timeframes, and not all the countries are represented in all dataframes. Changing the axis could result a more 'natural' table, but I left it as it is. My main goal is to examine the forest area, so the forest_are and forest_ratio tables are the most imporant ones. They have data between 1990 and 2015, so later I can drop the other columns from the other tables.

# %%
for k, v in df_dict.items():
    print(k + ": ")
    display(v.head())
# Out:
# forest_area:
#            geo      1990      1991      1992      1993      1994      1995  \
# 0  Afghanistan   13500.0   13500.0   13500.0   13500.0   13500.0   13500.0
# 1      Albania    7890.0    7870.0    7850.0    7830.0    7810.0    7790.0
# 2      Algeria   16700.0   16600.0   16500.0   16400.0   16300.0   16200.0
# 3      Andorra     160.0     160.0     160.0     160.0     160.0     160.0
# 4       Angola  610000.0  609000.0  607000.0  606000.0  605000.0  604000.0
#
#        1996      1997      1998    ...         2006      2007      2008  \
# 0   13500.0   13500.0   13500.0    ...      13500.0   13500.0   13500.0
# 1    7770.0    7750.0    7730.0    ...       7810.0    7800.0    7790.0
# 2   16100.0   16100.0   16000.0    ...      16100.0   16900.0   17700.0
# 3     160.0     160.0     160.0    ...        160.0     160.0     160.0
# 4  602000.0  601000.0  600000.0    ...     590000.0  589000.0  587000.0
#
#        2009      2010      2011      2012      2013      2014      2015
# 0   13500.0   13500.0   13500.0   13500.0   13500.0   13500.0   13500.0
# 1    7780.0    7760.0    7750.0    7740.0    7730.0    7720.0    7720.0
# 2   18400.0   19200.0   19300.0   19300.0   19400.0   19500.0   19600.0
# 3     160.0     160.0     160.0     160.0     160.0     160.0     160.0
# 4  586000.0  585000.0  584000.0  582000.0  581000.0  580000.0  579000.0
#
# [5 rows x 27 columns]
# forest_ratio:
#            geo   1990   1991   1992   1993   1994   1995   1996   1997   1998  \
# 0  Afghanistan   2.07   2.07   2.07   2.07   2.07   2.07   2.07   2.07   2.07
# 1      Albania  28.80  28.70  28.60  28.60  28.50  28.40  28.40  28.30  28.20
# 2      Algeria   0.70   0.70   0.69   0.69   0.69   0.68   0.68   0.67   0.67
# 3      Andorra  34.00  34.00  34.00  34.00  34.00  34.00  34.00  34.00  34.00
# 4       Angola  48.90  48.80  48.70  48.60  48.50  48.40  48.30  48.20  48.10
#
#    ...     2006   2007   2008   2009   2010   2011   2012   2013   2014   2015
# 0  ...     2.07   2.07   2.07   2.07   2.07   2.07   2.07   2.07   2.07   2.07
# 1  ...    28.50  28.50  28.40  28.40  28.30  28.30  28.30  28.20  28.20  28.20
# 2  ...     0.68   0.71   0.74   0.77   0.81   0.81   0.81   0.81   0.82   0.82
# 3  ...    34.00  34.00  34.00  34.00  34.00  34.00  34.00  34.00  34.00  34.00
# 4  ...    47.30  47.20  47.10  47.00  46.90  46.80  46.70  46.60  46.50  46.40
#
# [5 rows x 27 columns]
# population_total:
#            geo     1800     1801     1802     1803     1804     1805     1806  \
# 0  Afghanistan  3280000  3280000  3280000  3280000  3280000  3280000  3280000
# 1      Albania   410000   412000   413000   414000   416000   417000   418000
# 2      Algeria  2500000  2510000  2520000  2530000  2540000  2550000  2560000
# 3      Andorra     2650     2650     2650     2650     2650     2650     2650
# 4       Angola  1570000  1570000  1570000  1570000  1570000  1570000  1570000
#
#       1807     1808    ...         2009      2010      2011      2012  \
# 0  3280000  3280000    ...     28000000  28800000  29700000  30700000
# 1   420000   421000    ...      2960000   2940000   2930000   2920000
# 2  2570000  2580000    ...     35500000  36100000  36800000  37600000
# 3     2650     2650    ...        84500     84400     83800     82400
# 4  1570000  1570000    ...     22500000  23400000  24200000  25100000
#
#        2013      2014      2015      2016      2017      2018
# 0  31700000  32800000  33700000  34700000  35500000  36400000
# 1   2920000   2920000   2920000   2930000   2930000   2930000
# 2  38300000  39100000  39900000  40600000  41300000  42000000
# 3     80800     79200     78000     77300     77000     77000
# 4  26000000  26900000  27900000  28800000  29800000  30800000
#
# [5 rows x 220 columns]
# population_growth:
#            geo  1960  1961  1962  1963  1964  1965  1966  1967  1968  ...    \
# 0  Afghanistan  1.82  1.88  1.94  1.99  2.05  2.11  2.13  2.15  2.21  ...
# 1      Albania  3.02  3.12  3.06  2.95  2.88  2.75  2.63  2.63  2.84  ...
# 2      Algeria  2.51  2.49  2.47  2.49  2.56  2.66  2.76  2.84  2.88  ...
# 3      Andorra  7.05  6.94  6.69  6.56  6.24  6.00  5.75  5.50  5.31  ...
# 4       Angola  1.90  1.93  1.95  1.93  1.87  1.79  1.70  1.65  1.68  ...
#
#     2008   2009    2010   2011   2012   2013   2014   2015   2016   2017
# 0  2.510  2.570  2.8100  3.100  3.270  3.320  3.180  2.940  2.690  2.490
# 1 -0.767 -0.674 -0.4960 -0.269 -0.165 -0.183 -0.207 -0.291 -0.160 -0.092
# 2  1.620  1.720  1.8200  1.920  2.010  2.040  2.000  1.920  1.830  1.740
# 3  1.410  0.714 -0.0154 -0.830 -1.590 -2.010 -1.960 -1.540 -0.944 -0.410
# 4  3.560  3.570  3.5700  3.570  3.560  3.530  3.490  3.430  3.370  3.310
#
# [5 rows x 59 columns]
# population_density:
#            geo   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# 0  Afghanistan  11.90  12.00  12.20  12.30  12.50  12.70  12.90  13.10  13.30
# 1      Albania  46.10  47.00  48.00  49.20  50.50  51.80  53.30  54.70  56.30
# 2      Algeria   3.73   3.80   3.87   3.95   4.03   4.13   4.23   4.33   4.44
# 3      Andorra  13.20  14.20  15.40  16.70  18.10  19.60  21.30  22.90  24.70
# 4       Angola   3.65   3.74   3.83   3.92   4.01   4.10   4.19   4.27   4.36
#
#    ...     2091   2092   2093   2094   2095   2096   2097   2098   2099   2100
# 0  ...    110.0  110.0  110.0  109.0  109.0  109.0  109.0  108.0  108.0  108.0
# 1  ...     66.3   65.6   64.9   64.2   63.6   62.9   62.3   61.7   61.1   60.5
# 2  ...     26.4   26.4   26.4   26.4   26.4   26.4   26.3   26.3   26.3   26.3
# 3  ...    137.0  137.0  136.0  136.0  136.0  135.0  135.0  135.0  135.0  134.0
# 4  ...    125.0  127.0  128.0  130.0  131.0  133.0  134.0  136.0  137.0  139.0
#
# [5 rows x 152 columns]
# gdp_growth_pc:
#            geo     1801     1802     1803     1804     1805     1806     1807  \
# 0  Afghanistan  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000
# 1      Albania  0.10400  0.10400  0.10400  0.10400  0.10400  0.10400  0.10400
# 2      Algeria -0.00247 -0.00247 -0.00247 -0.00247 -0.00247 -0.00247 -0.00247
# 3      Andorra  0.16600  0.16600  0.16600  0.16600  0.16600  0.16600  0.16600
# 4       Angola  0.42500  0.42500  0.42500  0.42500  0.42500  0.42500  0.42500
#
#       1808     1809  ...    2010   2011   2012  2013   2014  2015  2016  \
# 0  0.00000  0.00000  ...   5.170  3.850  11.20  1.13  0.837  2.11  2.68
# 1  0.10400  0.10400  ...   2.980  2.490   2.28  1.72  2.610  3.82  4.72
# 2 -0.00247 -0.00247  ...   2.060  0.857   1.16  1.61  2.180  2.10  2.36
# 3  0.16600  0.16600  ...  -4.780 -4.300    NaN   NaN    NaN   NaN   NaN
# 4  0.42500  0.42500  ...   0.594  1.030   2.13  1.03  2.240  2.46  2.77
#
#     2017  2018  2019
# 0  2.760  3.02  3.38
# 1  5.030  5.03  5.23
# 2  2.500  2.63  2.68
# 3    NaN   NaN   NaN
# 4  0.262  3.46  3.55
#
# [5 rows x 220 columns]
# gdp_tot:
#            geo          1960          1961          1962          1963  \
# 0  Afghanistan           NaN           NaN           NaN           NaN
# 1      Albania           NaN           NaN           NaN           NaN
# 2      Algeria  2.740000e+10  2.370000e+10  1.900000e+10  2.560000e+10
# 3      Andorra           NaN           NaN           NaN           NaN
# 4       Angola           NaN           NaN           NaN           NaN
#
#            1964          1965          1966          1967          1968  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2  2.710000e+10  2.870000e+10  2.740000e+10  2.990000e+10  3.320000e+10
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
#
#        ...               2008          2009          2010          2011  \
# 0      ...       1.210000e+10  1.470000e+10  1.590000e+10  1.690000e+10
# 1      ...       1.110000e+10  1.150000e+10  1.190000e+10  1.220000e+10
# 2      ...       1.530000e+11  1.560000e+11  1.610000e+11  1.660000e+11
# 3      ...       3.680000e+09  3.550000e+09  3.360000e+09  3.200000e+09
# 4      ...       7.790000e+10  7.980000e+10  8.250000e+10  8.570000e+10
#
#            2012          2013          2014          2015          2016  \
# 0  1.940000e+10  2.010000e+10  2.060000e+10  2.090000e+10  2.140000e+10
# 1  1.240000e+10  1.250000e+10  1.280000e+10  1.300000e+10  1.350000e+10
# 2  1.710000e+11  1.760000e+11  1.830000e+11  1.900000e+11  1.960000e+11
# 3  3.150000e+09  3.160000e+09  3.230000e+09  3.260000e+09  3.320000e+09
# 4  9.020000e+10  9.630000e+10  1.010000e+11  1.040000e+11  1.030000e+11
#
#            2017
# 0  2.200000e+10
# 1  1.400000e+10
# 2  1.990000e+11
# 3  3.380000e+09
# 4  1.040000e+11
#
# [5 rows x 59 columns]
# gdp_pc:
#            geo    1960    1961    1962    1963    1964    1965    1966  \
# 0  Afghanistan     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1      Albania     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2      Algeria  2470.0  2080.0  1630.0  2130.0  2200.0  2280.0  2110.0
# 3      Andorra     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4       Angola     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      1967    1968   ...        2008     2009   2010     2011     2012  \
# 0     NaN     NaN   ...       445.0    525.0    553    569.0    630.0
# 1     NaN     NaN   ...      3780.0   3930.0   4090   4210.0   4280.0
# 2  2240.0  2410.0   ...      4390.0   4390.0   4460   4500.0   4560.0
# 3     NaN     NaN   ...     43900.0  42000.0  39700  38200.0  38200.0
# 4     NaN     NaN   ...      3580.0   3540.0   3530   3540.0   3590.0
#
#       2013     2014     2015     2016     2017
# 0    634.0    630.0    620.0    618.0    618.0
# 1   4330.0   4410.0   4520.0   4680.0   4870.0
# 2   4600.0   4680.0   4760.0   4830.0   4830.0
# 3  39100.0  40800.0  41800.0  43000.0  43900.0
# 4   3710.0   3750.0   3730.0   3580.0   3480.0
#
# [5 rows x 59 columns]
# agricultural_land_ratio:
#            geo  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...   \
# 0  Afghanistan  57.7  57.8  57.9  58.0  58.0  58.1  58.2  58.2  58.2  ...
# 1      Albania  45.0  45.0  45.0  44.9  45.1  45.3  45.4  45.3  45.1  ...
# 2      Algeria  19.1  18.9  18.7  18.5  18.5  18.5  18.6  18.6  18.6  ...
# 3      Andorra  55.3  55.3  55.3  55.3  55.3  55.3  55.3  55.3  55.3  ...
# 4       Angola  45.9  45.9  45.9  45.9  45.9  46.0  46.0  46.0  46.0  ...
#
#    2006  2007  2008  2009  2010  2011  2012  2013  2014  2015
# 0  58.1  58.1  58.1  58.1  58.1  58.1  58.1  58.1  58.1  58.1
# 1  40.9  40.8  43.1  43.8  43.8  43.8  43.8  43.3  42.9  42.9
# 2  17.3  17.3  17.3  17.4  17.4  17.4  17.4  17.4  17.4  17.4
# 3  46.3  44.2  44.2  44.2  42.1  42.1  39.9  40.0  40.0  40.0
# 4  46.2  46.3  46.3  46.8  46.8  47.3  47.3  47.5  47.5  47.5
#
# [5 rows x 56 columns]
# agricultural_gdp_ratio:
#            geo  1960  1961  1962  1963  1964  1965  1966  1967  1968  ...   \
# 0  Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1      Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2      Algeria  18.6  17.8  18.1  15.4  13.0  14.4  10.3  11.7  12.2  ...
# 3      Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4       Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#      2008    2009   2010    2011    2012    2013    2014   2015    2016  2017
# 0  24.700  29.100  26.10  23.600  23.600  22.600  22.000  20.50  21.000   NaN
# 1  16.800  16.800  18.00  18.200  18.800  19.600  20.000  19.80  19.900  19.0
# 2   6.590   9.340   8.47   8.110   8.770   9.850  10.300  11.60  12.300  12.3
# 3   0.442   0.435   0.50   0.535   0.612   0.577   0.496   0.47   0.492   NaN
# 4     NaN     NaN    NaN     NaN     NaN     NaN     NaN    NaN     NaN   NaN
#
# [5 rows x 59 columns]
# surface_area:
#            geo       1961       1962       1963       1964       1965  \
# 0  Afghanistan   653000.0   653000.0   653000.0   653000.0   653000.0
# 1      Albania    28800.0    28800.0    28800.0    28800.0    28800.0
# 2      Algeria  2380000.0  2380000.0  2380000.0  2380000.0  2380000.0
# 3      Andorra      470.0      470.0      470.0      470.0      470.0
# 4       Angola  1250000.0  1250000.0  1250000.0  1250000.0  1250000.0
#
#         1966       1967       1968       1969   ...          2008       2009  \
# 0   653000.0   653000.0   653000.0   653000.0   ...      653000.0   653000.0
# 1    28800.0    28800.0    28800.0    28800.0   ...       28800.0    28800.0
# 2  2380000.0  2380000.0  2380000.0  2380000.0   ...     2380000.0  2380000.0
# 3      470.0      470.0      470.0      470.0   ...         470.0      470.0
# 4  1250000.0  1250000.0  1250000.0  1250000.0   ...     1250000.0  1250000.0
#
#         2010     2011     2012     2013     2014     2015     2016     2017
# 0   653000.0   653000   653000   653000   653000   653000   653000   653000
# 1    28800.0    28800    28800    28800    28800    28800    28800    28800
# 2  2380000.0  2380000  2380000  2380000  2380000  2380000  2380000  2380000
# 3      470.0      470      470      470      470      470      470      470
# 4  1250000.0  1250000  1250000  1250000  1250000  1250000  1250000  1250000
#
# [5 rows x 58 columns]

# %% [markdown]
# The 'geo' column is a string in each dataframe, but most of the data is float or int. Some dataframes have both float and int, later I will convert these to the same type.

# %%
for k, v in df_dict.items():
    print(k + ": ")
    print(v.info())
# Out:
# forest_area:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 27 columns):
# geo     193 non-null object
# 1990    192 non-null float64
# 1991    192 non-null float64
# 1992    192 non-null float64
# 1993    192 non-null float64
# 1994    192 non-null float64
# 1995    192 non-null float64
# 1996    192 non-null float64
# 1997    192 non-null float64
# 1998    192 non-null float64
# 1999    192 non-null float64
# 2000    192 non-null float64
# 2001    192 non-null float64
# 2002    192 non-null float64
# 2003    192 non-null float64
# 2004    192 non-null float64
# 2005    192 non-null float64
# 2006    192 non-null float64
# 2007    192 non-null float64
# 2008    192 non-null float64
# 2009    192 non-null float64
# 2010    192 non-null float64
# 2011    193 non-null float64
# 2012    193 non-null float64
# 2013    193 non-null float64
# 2014    193 non-null float64
# 2015    193 non-null float64
# dtypes: float64(26), object(1)
# memory usage: 40.8+ KB
# None
# forest_ratio:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total

# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 58 columns):
# geo     194 non-null object
# 1961    187 non-null float64
# 1962    187 non-null float64
# 1963    187 non-null float64
# 1964    187 non-null float64
# 1965    187 non-null float64
# 1966    187 non-null float64
# 1967    187 non-null float64
# 1968    187 non-null float64
# 1969    187 non-null float64
# 1970    187 non-null float64
# 1971    187 non-null float64
# 1972    187 non-null float64
# 1973    187 non-null float64
# 1974    187 non-null float64
# 1975    187 non-null float64
# 1976    187 non-null float64
# 1977    187 non-null float64
# 1978    187 non-null float64
# 1979    187 non-null float64
# 1980    187 non-null float64
# 1981    187 non-null float64
# 1982    187 non-null float64
# 1983    187 non-null float64
# 1984    187 non-null float64
# 1985    187 non-null float64
# 1986    187 non-null float64
# 1987    187 non-null float64
# 1988    187 non-null float64
# 1989    187 non-null float64
# 1990    187 non-null float64
# 1991    190 non-null float64
# 1992    190 non-null float64
# 1993    191 non-null float64
# 1994    191 non-null float64
# 1995    191 non-null float64
# 1996    191 non-null float64
# 1997    191 non-null float64
# 1998    191 non-null float64
# 1999    191 non-null float64
# 2000    193 non-null float64
# 2001    193 non-null float64
# 2002    193 non-null float64
# 2003    193 non-null float64
# 2004    193 non-null float64
# 2005    193 non-null float64
# 2006    193 non-null float64
# 2007    193 non-null float64
# 2008    193 non-null float64
# 2009    193 non-null float64
# 2010    193 non-null float64
# 2011    194 non-null int64
# 2012    194 non-null int64
# 2013    194 non-null int64
# 2014    194 non-null int64
# 2015    194 non-null int64
# 2016    194 non-null int64
# 2017    194 non-null int64
# dtypes: float64(50), int64(7), object(1)
# memory usage: 88.0+ KB
# None

# %% [markdown]
# Here we can see some base statistics for every year in the dataframes. In our case this describes the statistics of countries for each year.

# %%
for k, v in df_dict.items():
    print(k + ": ")
    display(v.describe())
# Out:
# forest_area:
#                1990          1991          1992          1993          1994  \
# count  1.920000e+02  1.920000e+02  1.920000e+02  1.920000e+02  1.920000e+02
# mean   2.145522e+05  2.142037e+05  2.138679e+05  2.133308e+05  2.129860e+05
# std    7.964985e+05  7.956537e+05  7.949771e+05  7.938801e+05  7.932194e+05
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.425000e+03  3.417500e+03  3.417500e+03  3.407500e+03  3.407500e+03
# 50%    2.495000e+04  2.485000e+04  2.460000e+04  2.440000e+04  2.420000e+04
# 75%    1.047500e+05  1.047500e+05  1.047500e+05  1.055000e+05  1.055000e+05
# max    8.090000e+06  8.090000e+06  8.090000e+06  8.090000e+06  8.090000e+06
#
#                1995          1996          1997          1998          1999  \
# count  1.920000e+02  1.920000e+02  1.920000e+02  1.920000e+02  1.920000e+02
# mean   2.125831e+05  2.121329e+05  2.117903e+05  2.113730e+05  2.110449e+05
# std    7.922300e+05  7.911591e+05  7.905268e+05  7.895641e+05  7.889537e+05
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3
.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00
# 25%        ...       2.320000e+04  2.320000e+04  2.320000e+04  2.382500e+04
# 50%        ...       1.180000e+05  1.180000e+05  1.180000e+05  1.195000e+05
# 75%        ...       5.130000e+05  5.130000e+05  5.130000e+05  5.242500e+05
# max        ...       1.710000e+07  1.710000e+07  1.710000e+07  1.710000e+07
#
#                2012          2013          2014          2015          2016  \
# count  1.940000e+02  1.940000e+02  1.940000e+02  1.940000e+02  1.940000e+02
# mean   6.897728e+05  6.897728e+05  6.897625e+05  6.897625e+05  6.897625e+05
# std    1.920933e+06  1.920933e+06  1.920935e+06  1.920935e+06  1.920935e+06
# min    2.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00  2.000000e+00
# 25%    2.382500e+04  2.382500e+04  2.382500e+04  2.382500e+04  2.382500e+04
# 50%    1.195000e+05  1.195000e+05  1.195000e+05  1.195000e+05  1.195000e+05
# 75%    5.242500e+05  5.242500e+05  5.242500e+05  5.242500e+05  5.242500e+05
# max    1.710000e+07  1.710000e+07  1.710000e+07  1.710000e+07  1.710000e+07
#
#                2017
# count  1.940000e+02
# mean   6.897625e+05
# std    1.920935e+06
# min    2.000000e+00
# 25%    2.382500e+04
# 50%    1.195000e+05
# 75%    5.242500e+05
# max    1.710000e+07
#
# [8 rows x 57 columns]

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# With the 'datashape()' function I transform the 'geo' column (which is the country list) to the index of the dataframe. After that I drop all the years I don't want to use. The most important dartaframes (df_forest, df_forest_ratio) has data between 1990 and 2015, but I use 1992 and 2015, because df_forest_ratio has a lot of missing data in the first two years.
#
# 'datashape()' function uses 'inplace=True' argument inside. This way doesn't arose new object, and the dataframes in df_dict remaines the same.

# %%
df_dict = {k: shape_data(v) for k, v in df_dict.items()}
# Out:
# Column name 'geo' doesn't exist, returned the same dataframe.
# Column name 'geo' doesn't exist, returned the same dataframe.
# Column name 'geo' doesn't exist, returned the same dataframe.
# Column name 'geo' doesn't exist, returned the same dataframe.
# Column name 'geo' doesn't exist, returned the same dataframe.
# Column name 'geo' doesn't exist, returned the same dataframe.
# Column name 'geo' doesn't exist, returned the same dataframe.
# Column name 'geo' doesn't exist, returned the same dataframe.
# Column name 'geo' doesn't exist, returned the same dataframe.
# Column name 'geo' doesn't exist, returned the same dataframe.
# Column name 'geo' doesn't exist, returned the same dataframe.

# %% [markdown]
# After transforming the 'string' 'geo' column to index we have only numerical data, so it is easy to mass-convert the dataframes with 'int' and 'float' to 'float'. Unfortunatelly 'astype()' doesn't have 'inplace' argument, it gives back a new object, so I have to update df_dict as well.

# %%
df_gdp_pc = df_gdp_pc.astype(float)
df_dict['gdp_pc'] = df_gdp_pc
df_area = df_area.astype(float)
df_dict['surface_area'] = df_area

# %% [markdown]
# We will need an other dataframe, the agricultural land area. We calculate this from the country land area and the country agricaltural land area percent:

# %%
# we have the proper indexes now, so make a new dataframe
df_agr_area = df_agrtoland.apply(axis=1, func=(lambda x: x.multiply(df_area['2015'].loc[x.name])*0.01))
df_dict['agro_area'] = df_agr_area

# %%
for k, v in df_dict.items():
    print(k + ": ")
    display(v.head())
# Out:
# forest_area:
#                  1992      1993      1994      1995      1996      1997  \
# geo
# Afghanistan   13500.0   13500.0   13500.0   13500.0   13500.0   13500.0
# Albania        7850.0    7830.0    7810.0    7790.0    7770.0    7750.0
# Algeria       16500.0   16400.0   16300.0   16200.0   16100.0   16100.0
#
#                  2007      2008      2009      2010      2011      2012  \
# geo
# Afghanistan  26600000  27300000  28000000  28800000  29700000  30700000
# Albania       3020000   2990000   2960000   2940000   2930000   2920000
# Algeria      34300000  34900000  35500000  36100000  36800000  37600000
# Andorra         82700     83900     84500     84400     83800     82400
# Angola       21000000  21800000  22500000  23400000  24200000  25100000
#
#                  2013      2014      2015
# geo
# Afghanistan  31700000  32800000  33700000
# Albania       2920000   2920000   2920000
# Algeria      38300000  39100000  39900000
# Andorra         80800     79200     78000
# Angola       26000000  26900000  27900000
#
# [5 rows x 24 columns]
# population_growth:
#               1992  1993   1994   1995   1996    1997   1998   1999   2000  \
# geo
# Afghanistan  7.330  7.67  6.900  5.570  4.140  3.0900  2.590  2.820  3.490
# Albania     -0.606 -0.61 -0.614 -0.618 -0.622 -0.6250 -0.629 -0.633 -0.637
# Algeria      2.330  2.20  2.050  1.890  1.740  1.6000  1.490  1.410  1.350
# Andorra      3.840  3.48  2.760  1.850  0.796 -0.0513 -0.288  0.355  1.570
# Angola       3.250  3.30  3.210  3.040  2.860  2.7300  2.720  2.830  3.030
#
#               2001  ...     2006   2007   2008   2009    2010   2011   2012  \
# geo                 ...
# Afghanistan  4.250  ...    3.230  2.760  2.510  2.570  2.8100  3.100  3.270
# Albania     -0.938  ...   -0.631 -0.756 -0.767 -0.674 -0.4960 -0.269 -0.165
# Algeria      1.300  ...    1.460  1.530  1.620  1.720  1.8200  1.920  2.010
# Andorra      2.940  ...    2.660  2.070  1.410  0.714 -0.0154 -0.830 -1.590
# Angola       3.250  ...    3.570  3.560  3.560  3.570  3.5700  3.570  3.560
#
#               2013   2014   2015
# geo
# Afghanistan  3.320  3.180  2.940
# Albania     -0.183 -0.207 -0.291
# Algeria      2.040  2.000  1.920
# Andorra     -2.010 -1.960 -1.540
# Angola       3.530  3.490  3.430
#
# [5 rows x 24 columns]
# population_density:
#               1992   1993   1994   1995   1996   1997   1998   1999   2000  \
# geo
# Afghanistan   21.4   23.1   24.8   26.2   27.3   28.2   28.9   29.7   30.8
# Albania      118.0  116.0  115.0  113.0  113.0  113.0  113.0  114.0  114.0
# Algeria       11.4   11.7   11.9   12.1   12.3   12.5   12.7   12.9   13.1
# Andorra      125.0  130.0  133.0  136.0  137.0  137.0  136.0  137.0  139.0
# Angola        10.4   10.8   11.1   11.4   11.8   12.1   12.4   12.8   13.2
#
#               2001  ...     2006   2007   2008   2009   2010   2011   2012  \
# geo                 ...
# Afghanistan   32.1  ...     39.7   40.8   41.8   42.9   44.1   45.5   47.0
# Albania      114.0  ...    111.0  110.0  109.0  108.0  107.0  107.0  107.0
# Algeria       13.3  ...     14.2   14.4   14.6   14.9   15.2   15.5   15.8
# Andorra      143.0  ...    172.0  176.0  178.0  180.0  180.0  178.0  175.0
# Angola        13.6  ...     16.3   16.8   17.5   18.1   18.7   19.4   20.1
#
#               2013   2014   2015
# geo
# Afghanistan   48.6   50.2   51.7
# Albania      107.0  107.0  107.0
# Algeria       16.1   16.4   16.7
# Andorra      172.0  169.0  166.0
# Angola        20.9   21.6   22.3
#
# [5 rows x 24 columns]
# gdp_growth_pc:
#               1992   1993   1994    1995   1996    1997   1998   1999    2000  \
# geo
# Afghanistan -7.950 -13.90 -10.40  20.300   2.66   2.820   2.83  2.710 -1.0500
# Albania     -8.100   8.78   7.44  12.600   8.65 -10.600  12.30  9.580  6.7900
# Algeria     -0.752  -4.44  -3.07   1.710   1.94  -0.558   3.50  1.680  0.9950
# Andorra     -3.740  -5.65  -1.65  -0.114   3.09   8.590   3.30  4.010  0.4010
# Angola      -8.830 -26.40  -1.86  11.600  16.60   2.700  -2.63  0.387 -0.0561
#
#                2001  ...     2006   2007    2008    2009   2010   2011   2012  \
# geo                  ...
# Afghanistan -10.400  ...    1.590  10.80   0.117  17.300  5.170  3.850  11.20
# Albania       6.690  ...    5.270   5.41   6.840   2.910  2.980  2.490   2.28
# Algeria       1.130  ...    0.188   1.85   0.472   0.179  2.060  0.857   1.16
# Andorra      10.000  ...    2.370  -1.70  -5.600  -6.310 -4.780 -4.300  -4.30
# Angola       -0.171  ...   15.000  19.60  10.600  -0.464  0.594  1.030   2.13
#
#              2013   2014  2015
# geo
# Afghanistan  1.13  0.837  2.11
# Albania      1.72  2.610  3.82
# Algeria      1.61  2.180  2.10
# Andorra     -4.30 -4.300 -4.30
# Angola       1.03  2.240  2.46
#
# [5 rows x 24 columns]
# gdp_tot:
#                      1992          1993          1994          1995  \
# geo
# Afghanistan  8.010000e+09  8.010000e+09  8.010000e+09  8.010000e+09
# Albania      4.180000e+09  4.580000e+09  4.970000e+09  5.630000e+09
# Algeria      9.250000e+10  9.060000e+10  8.980000e+10  9.320000e+10
# Andorra      2.020000e+09  2.000000e+09  2.050000e+09  2.100000e+09
# Angola       2.380000e+10  1.810000e+10  1.830000e+10  2.110000e+10
#
#                      1996          1997          1998          1999  \
# geo
# Afghanistan  8.010000e+09  8.010000e+09  8.010000e+09  8.010000e+09
# Albania      6.140000e+09  5.470000e+09  5.970000e+09  6.770000e+09
# Algeria      9.700000e+10  9.810000e+10  1.030000e+11  1.060000e+11
# Andorra      2.200000e+09  2.400000e+09  2.480000e+09  2.580000e+09
# Angola       2.390000e+10  2.570000e+10  2.690000e+10  2.740000e+10
#
#                      2000          2001      ...               2006  \
# geo                                          ...
# Afghanistan  8.010000e+09  8.010000e+09      ...       1.030000e+10
# Albania      7.220000e+09  7.800000e+09      ...       1.010000e+10
# Algeria      1.100000e+11  1.140000e+11      ...       1.450000e+11
# Andorra      2.670000e+09  2.790000e+09      ...       4.030000e+09
# Angola       2.830000e+10  2.950000e+10      ...       5.560000e+10
#
#                      2007          2008          2009          2010  \
# geo
# Afghanistan  1.170000e+10  1.210000e+10  1.470000e+10  1.590000e+10
# Albania      1.070000e+10  1.110000e+10  1.150000e+10  1.190000e+10
# Algeria      1.500000e+11  1.530000e+11  1.560000e+11  1.610000e+11
# Andorra      4.030000e+09  3.680000e+09  3.550000e+09  3.360000e+09
# Angola       6.840000e+10  7.790000e+10  7.980000e+10  8.250000e+10
#
#                      2011          2012          2013          2014  \
# geo
# Afghanistan  1.690000e+10  1.940000e+10  2.010000e+10  2.060000e+10
# Albania      1.220000e+10  1.240000e+10  1.250000e+10  1.280000e+10
# Algeria      1.660000e+11  1.710000e+11  1.760000e+11  1.830000e+11
# Andorra      3.200000e+09  3.150000e+09  3.160000e+09  3.230000e+09
# Angola       8.570000e+10  9.020000e+10  9.630000e+10  1.010000e+11
#
#                      2015
# geo
# Afghanistan  2.090000e+10
# Albania      1.300000e+10
# Algeria      1.900000e+11
# Andorra      3.260000e+09
# Angola       1.040000e+11
#
# [5 rows x 24 columns]
# gdp_pc:
#                 1992     1993     1994     1995     1996     1997     1998  \
# geo
# Afghanistan      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# Albania       1290.0   1420.0   1550.0   1760.0   1940.0   1740.0   1910.0
# Algeria       3400.0   3260.0   3160.0   3220.0   3300.0   3280.0   3400.0
# Andorra      34300.0  32800.0  32600.0  32900.0  34200.0  37300.0  38600.0
# Angola        1830.0   1350.0   1320.0   1480.0   1630.0   1700.0   1730.0
#
#                 1999     2000     2001   ...        2006     2007     2008  \
# geo                                      ...
# Afghanistan      NaN      NaN      NaN   ...       398.0    440.0    445.0
# Albania       2180.0   2340.0   2550.0   ...      3380.0   3610.0   3780.0
# Algeria       3460.0   3540.0   3600.0   ...      4280.0   4360.0   4390.0
# Andorra      40000.0  40800.0  41400.0   ...     49700.0  48700.0  43900.0
# Angola        1720.0   1720.0   1740.0   ...      2740.0   3260.0   3580.0
#
#                 2009     2010     2011     2012     2013     2014     2015
# geo
# Afghanistan    525.0    553.0    569.0    630.0    634.0    630.0    620.0
# Albania       3930.0   4090.0   4210.0   4280.0   4330.0   4410.0   4520.0
# Algeria       4390.0   4460.0   4500.0   4560.0   4600.0   4680.0   4760.0
# Andorra      42000.0  39700.0  38200.0  38200.0  39100.0  40800.0  41800.0
# Angola        3540.0   3530.0   3540.0   3590.0   3710.0   3750.0   3730.0
#
# [5 rows x 24 columns]
# agricultural_land_ratio:
#              1992  1993  1994  1995  1996  1997  1998  1999  2000  2001  ...   \
# geo                                                                      ...
# Afghanistan  58.3  58.1  57.9  57.8  57.8  57.9  58.0  57.8  57.8  57.8  ...
# Albania      41.1  41.1  41.1  41.1  41.3  41.4  41.6  41.8  41.8  41.6  ...
# Algeria      16.3  16.3  16.6  16.6  16.6  16.7  16.7  16.7  16.8  16.8  ...
# Andorra      48.9  48.9  48.9  48.9  48.9  48.9  48.9  48.9  48.9  48.4  ...
# Angola       46.1  46.1  46.1  46.1  46.1  46.1  46.1  46.0  46.0  46.0  ...
#
#              2006  2007  2008  2009  2010  2011  2012  2013  2014  2015
# geo
# Afghanistan  58.1  58.1  58.1  58.1  58.1  58.1  58.1  58.1  58.1  58.1
# Albania      40.9  40.8  43.1  43.8  43.8  43.8  43.8  43.3  42.9  42.9
# Algeria      17.3  17.3  17.3  17.4  17.4  17.4  17.4  17.4  17.4  17.4
# Andorra      46.3  44.2  44.2  44.2  42.1  42.1  39.9  40.0  40.0  40.0
# Angola       46.2  46.3  46.3  46.8  46.8  47.3  47.3  47.5  47.5  47.5
#
# [5 rows x 24 columns]
# agricultural_gdp_ratio:
# Andorra         229.83     229.83     229.83     229.83     229.83     229.83
# Angola       576250.00  576250.00  576250.00  576250.00  576250.00  576250.00
#
#                   1998       1999       2000       2001    ...          2006  \
# geo                                                        ...
# Afghanistan  378740.00  377434.00  377434.00  377434.00    ...     379393.00
# Albania       11980.80   12038.40   12038.40   11980.80    ...      11779.20
# Algeria      397460.00  397460.00  399840.00  399840.00    ...     411740.00
# Andorra         229.83     229.83     229.83     227.48    ...        217.61
# Angola       576250.00  575000.00  575000.00  575000.00    ...     577500.00
#
#                   2007       2008       2009       2010       2011       2012  \
# geo
# Afghanistan  379393.00  379393.00  379393.00  379393.00  379393.00  379393.00
# Albania       11750.40   12412.80   12614.40   12614.40   12614.40   12614.40
# Algeria      411740.00  411740.00  414120.00  414120.00  414120.00  414120.00
# Andorra         207.74     207.74     207.74     197.87     197.87     187.53
# Angola       578750.00  578750.00  585000.00  585000.00  591250.00  591250.00
#
#                  2013      2014      2015
# geo
# Afghanistan  379393.0  379393.0  379393.0
# Albania       12470.4   12355.2   12355.2
# Algeria      414120.0  414120.0  414120.0
# Andorra         188.0     188.0     188.0
# Angola       593750.0  593750.0  593750.0
#
# [5 rows x 24 columns]

# %% [markdown]
# I don't check for duplicates in the data, because our index is the country list and all index must be unique, but we have some missing data.
#
# First we check how many countries has missing data in our dataframes. We can see that the GDP dataframes are the most incomplete.

# %%
for k, v in df_dict.items():
    print(k + " null values: ")
    print(v.isnull().any(axis=1).sum())
# Out:
# forest_area null values:
# 0
# forest_ratio null values:
# 0
# population_total null values:
# 0
# population_growth null values:
# 0
# population_density null values:
# 0
# gdp_growth_pc null values:
# 0
# gdp_tot null values:
# 0
# gdp_pc null values:
# 24
# agricultural_land_ratio null values:
# 7
# agricultural_gdp_ratio null values:
# 48
# surface_area null values:
# 3
# agro_area null values:
# 7

# %% [markdown]
# Check how many missing data the year columns have:

# %%
for k, v in df_dict.items():
    print(k + ": ")
    print(v.isna().sum())
# Out:
# forest_area:
# 1992    0
# 1993    0
# 1994    0
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# 2000    0
# 2001    0
# 2002    0
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# dtype: int64
# forest_ratio:
# 1992    0
# 1993    0
# 1994    0
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# 2000    0
# 2001    0
# 2002    0
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# dtype: int64
# population_total:
# 1992    0
# 1993    0
# 1994    0
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# 2000    0
# 2001    0
# 2002    0
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# dtype: int64
# population_growth:
# 1992    0
# 1993    0
# 1994    0
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# 2000    0
# 2001    0
# 2002    0
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# dtype: int64
# population_density:
# 1992    0
# 1993    0
# 1994    0
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# 2000    0
# 2001    0
# 2002    0
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# dtype: int64
# gdp_growth_pc:
# 1992    0
# 1993    0
# 1994    0
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# 2000    0
# 2001    0
# 2002    0
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# dtype: int64
# gdp_tot:
# 1992    0
# 1993    0
# 1994    0
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# 2000    0
# 2001    0
# 2002    0
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# dtype: int64
# gdp_pc:
# 1992    22
# 1993    21
# 1994    19
# 1995    10
# 1996     8
# 1997     6
# 1998     6
# 1999     5
# 2000     2
# 2001     1
# 2002     0
# 2003     0
# 2004     0
# 2005     0
# 2006     0
# 2007     0
# 2008     0
# 2009     0
# 2010     0
# 2011     0
# 2012     1
# 2013     1
# 2014     1
# 2015     2
# dtype: int64
# agricultural_land_ratio:
# 1992    7
# 1993    4
# 1994    4
# 1995    4
# 1996    4
# 1997    4
# 1998    4
# 1999    4
# 2000    2
# 2001    2
# 2002    2
# 2003    2
# 2004    2
# 2005    2
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# dtype: int64
# agricultural_gdp_ratio:
# 1992    40
# 1993    37
# 1994    31
# 1995    12
# 1996    13
# 1997    11
# 1998    11
# 1999    11
# 2000     5
# 2001     4
# 2002     4
# 2003     4
# 2004     3
# 2005     4
# 2006     2
# 2007     2
# 2008     3
# 2009     3
# 2010     4
# 2011     4
# 2012     4
# 2013     4
# 2014     5
# 2015     7
# dtype: int64
# surface_area:
# 1992    3
# 1993    2
# 1994    2
# 1995    2
# 1996    2
# 1997    2
# 1998    2
# 1999    2
# 2000    0
# 2001    0
# 2002    0
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# dtype: int64
# agro_area:
# 1992    7
# 1993    4
# 1994    4
# 1995    4
# 1996    4
# 1997    4
# 1998    4
# 1999    4
# 2000    2
# 2001    2
# 2002    2
# 2003    2
# 2004    2
# 2005    2
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# dtype: int64

# %% [markdown]
# I want to fill missing data later, but if a country in the most important dataframes has too many missing data, I will drop it. In forest_area table 'South Sudan' has data only at the end of he period, and fortunatelly it isn't among the countries with largest the largest forest area, so I will drop it.

# %%
for k, v in df_dict.items():
    isnull_rows = v.isnull().any(axis=1)
    print(k + ": ")
    display(v[isnull_rows])
# Out:
# forest_area:
# Empty DataFrame
# Columns: [1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]
# Index: []
#
# [0 rows x 24 columns]
# forest_ratio:
# Empty DataFrame
# Columns: [1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]
# Index: []
#
# [0 rows x 24 columns]
# population_total:
# Empty DataFrame
# Columns: [1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]
# Index: []
#
# [0 rows x 24 columns]
# population_growth:
# Empty DataFrame
# Columns: [1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]
# Index: []
#
# [0 rows x 24 columns]
# population_density:
# Empty DataFrame
# Columns: [1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]
# Index: []
#
# [0 rows x 24 columns]
# gdp_growth_pc:
# Empty DataFrame
# Columns: [1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]
# Index: []
#
# [0 rows x 24 columns]
# gdp_tot:
# Empty DataFrame
# Columns: [1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]
# Index: []
#
# [0 rows x 24 columns]
# gdp_pc:
#                            1992     1993     1994     1995     1996     1997  \
# geo
# Afghanistan                 NaN      NaN      NaN      NaN      NaN      NaN
# Bosnia and Herzegovina      NaN      NaN    699.0    867.0   1670.0   2260.0
# Cambodia                    NaN    510.0    321.0    342.0    351.0    355.0
# Croatia                     NaN      NaN      NaN   8480.0   9320.0   9770.0
# Eritrea                   378.0    432.0    526.0    540.0    585.0    622.0
# Estonia                     NaN      NaN      NaN   7310.0   7820.0   8840.0
# Haiti                       NaN      NaN      NaN      NaN    757.0    764.0
# Iceland                     NaN      NaN      NaN      NaN  31300.0  32600.0
# Kuwait                      NaN      NaN      NaN  41500.0  41200.0  40100.0
# Latvia                      NaN      NaN      NaN   5140.0   5320.0   5860.0
# Libya                       NaN      NaN      NaN      NaN      NaN      NaN
# Lithuania                   NaN      NaN      NaN   5320.0   5640.0   6150.0
# Maldives                    NaN      NaN      NaN   4600.0   4860.0   5170.0
# Moldova                     NaN      NaN      NaN   1090.0   1030.0   1050.0
# Montenegro                  NaN      NaN      NaN      NaN      NaN   5010.0
# Palau                       NaN      NaN      NaN      NaN      NaN      NaN
# Palestine                   NaN      NaN   1530.0   1560.0   1600.0   1900.0
# Qatar                       NaN      NaN      NaN      NaN      NaN      NaN
# San Marino                  NaN      NaN      NaN      NaN      NaN  60800.0
# Sao Tome and Principe       NaN      NaN      NaN      NaN      NaN      NaN
# Serbia                      NaN      NaN      NaN   3150.0   3230.0   3480.0
# Slovenia                    NaN      NaN      NaN  15100.0  15600.0  16400.0
# Timor-Leste                 NaN      NaN      NaN      NaN      NaN      NaN
# Venezuela               13100.0  12900.0  12300.0  12500.0  12300.0  12800.0
#
#                            1998     1999     2000     2001   ...        2006  \
# geo                                                          ...
# Afghanistan                 NaN      NaN      NaN      NaN   ...       398.0
# Bosnia and Herzegovina   2610.0   2850.0   3000.0   3130.0   ...      4160.0
# Cambodia                  362.0    398.0    431.0    454.0   ...       669.0
# Croatia                 10100.0   9900.0  10600.0  10900.0   ...     13800.0
# Eritrea                   621.0    606.0    572.0    603.0   ...       536.0
# Estonia                  9290.0   9190.0  10100.0  10800.0   ...     16300.0
# Haiti                     766.0    773.0    767.0    746.0   ...       693.0
# Iceland                 34500.0  35400.0  36600.0  37500.0   ...     43700.0
# Kuwait                  38900.0  35800.0  35800.0  35100.0   ...     49300.0
# Latvia                   6300.0   6520.0   6930.0   7480.0   ...     12300.0
# Libya                       NaN   8780.0   8970.0   8670.0   ...     11200.0
# Lithuania                6660.0   6630.0   6930.0   7450.0   ...     11500.0
# Maldives                 5460.0   5680.0   5780.0   5420.0   ...      6740.0
# Moldova                   978.0    946.0    968.0   1030.0   ...      1450.0
# Montenegro               5280.0   4790.0   4950.0   4980.0   ...      6070.0
# Palau                       NaN      NaN   9340.0   9750.0   ...     10400.0
# Palau                    9520.0   9690.0  10600.0
# Palestine                2520.0   2420.0   2640.0
# Qatar                   68900.0  67900.0  67300.0
# San Marino              53800.0  52700.0  52500.0
# Sao Tome and Principe    1190.0   1240.0   1260.0
# Serbia                   5670.0   5590.0   5660.0
# Slovenia                22600.0  23200.0  23700.0
# Timor-Leste              3530.0   2550.0   3010.0
# Venezuela               14500.0  13700.0      NaN
#
# [24 rows x 24 columns]
# agricultural_land_ratio:
#                  1992  1993  1994  1995  1996  1997  1998  1999  2000  2001  \
# geo
# Belgium           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  45.9  45.8
# Czech Republic    NaN  55.4  55.4  55.4  55.4  55.4  55.4  55.4  55.4  55.4
# Eritrea           NaN  73.3  73.3  73.3  72.7  72.9  73.9  73.9  74.6  74.6
# Luxembourg        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  49.4  49.4
# Montenegro        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Serbia            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Slovak Republic   NaN  50.9  50.9  50.9  50.8  50.8  50.8  50.8  50.7  46.9
#
#                  ...   2006  2007  2008  2009  2010  2011  2012  2013  2014  \
# geo              ...
# Belgium          ...   45.6  45.1  45.1  45.0  44.8  44.1  44.0  44.1  44.0
# Czech Republic   ...   55.1  55.0  54.9  54.9  54.8  54.8  54.7  54.6  54.6
# Eritrea          ...   75.0  75.0  75.0  75.2  75.2  75.2  75.2  75.2  75.2
# Luxembourg       ...   49.8  50.6  50.6  50.5  50.6  50.7  50.7  50.5  50.6
# Montenegro       ...   38.3  38.2  38.1  38.2  38.1  38.1  38.1  16.6  17.1
# Serbia           ...   40.4  40.9  41.2  40.2  40.3  40.3  39.6  39.9  40.1
# Slovak Republic  ...   40.3  40.1  40.3  40.1  40.4  40.1  40.1  40.1  40.0
#
#                  2015
# geo
# Belgium          43.9
# Czech Republic   54.6
# Eritrea          75.2
# Luxembourg       50.7
# Montenegro       17.2
# Serbia           39.7
# Slovak Republic  40.0
#
# [7 rows x 24 columns]
# agricultural_gdp_ratio:
#                          1992    1993   1994    1995   1996   1997    1998  \
# geo
# Afghanistan               NaN     NaN    NaN     NaN    NaN    NaN     NaN
# Andorra                   NaN     NaN    NaN     NaN    NaN    NaN     NaN
# Angola                   7.89  10.500   6.08   6.650   7.03   9.00  12.900
# Bahrain                  0.91   0.851   0.86   0.863    NaN    NaN     NaN
# Belgium                   NaN     NaN    NaN   1.300   1.32   1.33   1.250
# Bosnia and Herzegovina    NaN     NaN  35.90  20.700  20.70  17.50  16.000
# Cambodia                  NaN  45.300  45.60  47.700  44.50  44.40  44.500
# Croatia                   NaN     NaN    NaN   5.990   5.88   5.50   5.700
# Czech Republic            NaN   4.180   4.20   3.960   3.62   3.32   3.400
# Equatorial Guinea         NaN     NaN    NaN     NaN    NaN    NaN     NaN
# Eritrea                 27.40  19.400  21.90  18.800  16.20  15.10  23.400
# Estonia                   NaN     NaN    NaN   5.060   4.74   4.52   5.320
# Greece                    NaN     NaN    NaN   7.380   6.58   6.24   5.970
# Hungary                   NaN     NaN    NaN   7.090   7.18   6.26   5.960
# Iceland                   NaN     NaN    NaN     NaN    NaN   8.29   8.200
# Ireland                   NaN     NaN    NaN   5.770   4.84   3.91   3.480
# Luxembourg        1310.54   1307.95   1310.54   1313.13   1313.13   1307.95
# Montenegro        5257.80   5271.60   5257.80   5257.80   5257.80   2290.80
# Serbia           36420.80  35536.80  35625.20  35625.20  35006.40  35271.60
# Slovak Republic  19747.00  19649.00  19796.00  19649.00  19649.00  19649.00
#
#                      2014      2015
# geo
# Belgium          13420.00  13389.50
# Czech Republic   43079.40  43079.40
# Eritrea          88736.00  88736.00
# Luxembourg        1310.54   1313.13
# Montenegro        2359.80   2373.60
# Serbia           35448.40  35094.80
# Slovak Republic  19600.00  19600.00
#
# [7 rows x 24 columns]

# %% [markdown]
# Drop 'South Sudan' from every dataframe:

# %%
for k, v in df_dict.items():
    if 'South Sudan' in v.index:
        v.drop(['South Sudan'])
        print(k + ": South Sudan dropped")
    else:
        print(k + ": no occurence")
# Out:
# forest_area: no occurence
# forest_ratio: no occurence
# population_total: South Sudan dropped
# population_growth: South Sudan dropped
# population_density: South Sudan dropped
# gdp_growth_pc: South Sudan dropped
# gdp_tot: no occurence
# gdp_pc: no occurence
# agricultural_land_ratio: no occurence
# agricultural_gdp_ratio: no occurence
# surface_area: no occurence
# agro_area: no occurence

# %% [markdown]
# In the above step I dropped a country from each dataframe, because it didn't have proper forest data.
# Here I will drop countries from the distinct dataframes if they have too few data in the corresponding dataframe:

# %%
#drop rows with less than 10 
for k, v in df_dict.items():
    v.drop(v[v.count(axis=1) < 10].index, inplace=True)

# %% [markdown]
# ### Missing values
# Choosing the method to fill missing values not a trivial one. For example at the case of the total gdp of a country linear regression can be a good estimate for missing values most of the time, but the mean would provide a very bad estimation at the beginning and end of the period. But for the gdp/capita the mean can be a not so bad choice.
# For simplicity instead of finding some optimal estimator for each missing value, I used only one method for all. First I use the closest earlier year value to fill the missing value. After this I can have missing values at the beginning of the period, so for them I use the earliest existing year value.

# %%
# fill missing values
for k, v in df_dict.items():
    print(k + ": ")    
    v.fillna(method='ffill', axis=1, inplace=True)
    v.fillna(method='bfill', axis=1, inplace=True)
    display(v.head())
# Out:
# forest_area:
#                  1992      1993      1994      1995      1996      1997  \
# geo
# Afghanistan   13500.0   13500.0   13500.0   13500.0   13500.0   13500.0
# Albania        7850.0    7830.0    7810.0    7790.0    7770.0    7750.0
# Algeria       16500.0   16400.0   16300.0   16200.0   16100.0   16100.0
# Andorra         160.0     160.0     160.0     160.0     160.0     160.0
# Angola       607000.0  606000.0  605000.0  604000.0  602000.0  601000.0
#
#                  1998      1999      2000      2001    ...         2006  \
# geo                                                    ...
# Afghanistan   13500.0   13500.0   13500.0   13500.0    ...      13500.0
# Albania        7730.0    7710.0    7690.0    7720.0    ...       7810.0
# Algeria       16000.0   15900.0   15800.0   15700.0    ...      16100.0
# Andorra         160.0     160.0     160.0     160.0    ...        160.0
# Angola       600000.0  599000.0  597000.0  596000.0    ...     590000.0
#
#                  2007      2008      2009      2010      2011      2012  \
# geo
# Afghanistan   13500.0   13500.0   13500.0   13500.0   13500.0   13500.0
# Albania        7800.0    7790.0    7780.0    7760.0    7750.0    7740.0
# Algeria       16900.0   17700.0   18400.0   19200.0   19300.0   19300.0
# Andorra         160.0     160.0     160.0     160.0     160.0     160.0
# Angola       589000.0  587000.0  586000.0  585000.0  584000.0  582000.0
#
#                  2013      2014      2015
# geo
# Afghanistan   13500.0   13500.0   13500.0
# Albania        7730.0    7720.0    7720.0
# Algeria       19400.0   19500.0   19600.0
# Andorra         160.0     160.0     160.0
# Angola       581000.0  580000.0  579000.0
#
# [5 rows x 24 columns]
# forest_ratio:
#               1992   1993   1994   1995   1996   1997   1998   1999   2000  \
# geo
# Afghanistan   2.07   2.07   2.07   2.07   2.07   2.07   2.07   2.07   2.07
# Albania      28.60  28.60  28.50  28.40  28.40  28.30  28.20  28.10  28.10
# Algeria       0.69   0.69   0.69   0.68   0.68   0.67   0.67   0.67   0.66
# Andorra      34.00  34.00  34.00  34.00  34.00  34.00  34.00  34.00  34.00
# Angola       48.70  48.60  48.50  48.40  48.30  48.20  48.10  48.00  47.90
#
#               2001  ...     2006   2007   2008   2009   2010   2011   2012  \
# geo                 ...
# Afghanistan   2.07  ...     2.07   2.07   2.07   2.07   2.07   2.07   2.07
# Albania      28.20  ...    28.50  28.50  28.40  28.40  28.30  28.30  28.30
# Algeria       0.66  ...     0.68   0.71   0.74   0.77   0.81   0.81   0.81
# Andorra      34.00  ...    34.00  34.00  34.00  34.00  34.00  34.00  34.00
# Angola       47.80  ...    47.30  47.20  47.10  47.00  46.90  46.80  46.70
#
#               2013   2014   2015
# geo
# Afghanistan   2.07   2.07   2.07
# Albania      28.20  28.20  28.20
# Algeria       0.81   0.82   0.82
# Andorra      34.00  34.00  34.00
# Angola       46.60  46.50  46.40
#
# [5 rows x 24 columns]
# population_total:
#                  1992      1993      1994      1995      1996      1997  \
# geo
# Afghanistan  14000000  15100000  16200000  17100000  17800000  18400000
# Albania       3240000   3190000   3140000   3110000   3090000   3090000
# Algeria      27200000  27800000  28400000  28900000  29400000  29900000
# Andorra         58900     61000     62700     63900     64400     64300
# Angola       13000000  13400000  13800000  14300000  14700000  15100000
#
#                  1998      1999      2000      2001    ...         2006  \
# geo                                                    ...
# Afghanistan  18900000  19400000  20100000  21000000    ...     25900000
# Albania       3100000   3120000   3120000   3120000    ...      3050000
# Algeria      30300000  30800000  31200000  31600000    ...     33800000
# Andorra         64100     64400     65400     67300    ...        81000
# Angola       15500000  15900000  16400000  17000000    ...     20300000
#
#                  2007      2008      2009      2010      2011      2012  \
# geo
# Afghanistan  26600000  27300000  28000000  28800000  29700000  30700000
# Albania       3020000   2990000   2960000   2940000   2930000   2920000
# Algeria      34300000  34900000  35500000  36100000  36800000  37600000
# Andorra         82700     83900     84500     84400     83800     82400
# Angola       21000000  21800000  22500000  23400000  24200000  25100000
#
#                  2013      2014      2015
# geo
# Afghanistan  31700000  32800000  33700000
# Albania       2920000   2920000   2920000
# Algeria      38300000  39100000  39900000
# Andorra         80800     79200     78000
# Angola       26000000  26900000  27900000
#
# [5 rows x 24 columns]
# population_growth:
#               1992  1993   1994   1995   1996    1997   1998   1999   2000  \
# geo
# Afghanistan  7.330  7.67  6.900  5.570  4.140  3.0900  2.590  2.820  3.490
# Albania     -0.606 -0.61 -0.614 -0.618 -0.622 -0.6250 -0.629 -0.633 -0.637
# Algeria      2.330  2.20  2.050  1.890  1.740  1.6000  1.490  1.410  1.350
# Andorra      3.840  3.48  2.760  1.850  0.796 -0.0513 -0.288  0.355  1.570
# Angola       3.250  3.30  3.210  3.040  2.860  2.7300  2.720  2.830  3.030
#
#               2001  ...     2006   2007   2008   2009    2010   2011   2012  \
# geo                 ...
# Afghanistan  4.250  ...    3.230  2.760  2.510  2.570  2.8100  3.100  3.270
# Albania     -0.938  ...   -0.631 -0.756 -0.767 -0.674 -0.4960 -0.269 -0.165
# Algeria      1.300  ...    1.460  1.530  1.620  1.720  1.8200  1.920  2.010
# Andorra      2.940  ...    2.660  2.070  1.410  0.714 -0.0154 -0.830 -1.590
# Angola       3.250  ...    3.570  3.560  3.560  3.570  3.5700  3.570  3.560
#
#               2013   2014   2015
# geo
# Afghanistan  3.320  3.180  2.940
# Albania     -0.183 -0.207 -0.291
# Algeria      2.040  2.000  1.920
# Andorra     -2.010 -1.960 -1.540
# Angola       3.530  3.490  3.430
#
# [5 rows x 24 columns]
# population_density:
#               1992   1993   1994   1995   1996   1997   1998   1999   2000  \
# geo
# Afghanistan   21.4   23.1   24.8   26.2   27.3   28.2   28.9   29.7   30.8
# Albania      118.0  116.0  115.0  113.0  113.0  113.0  113.0  114.0  114.0
# Algeria       11.4   11.7   11.9   12.1   12.3   12.5   12.7   12.9   13.1
# Andorra      125.0  130.0  133.0  136.0  137.0  137.0  136.0  137.0  139.0
# Angola        10.4   10.8   11.1   11.4   11.8   12.1   12.4   12.8   13.2
#
#               2001  ...     2006   2007   2008   2009   2010   2011   2012  \
# geo                 ...
# Afghanistan   32.1  ...     39.7   40.8   41.8   42.9   44.1   45.5   47.0
# Albania      114.0  ...    111.0  110.0  109.0  108.0  107.0  107.0  107.0
# Algeria       13.3  ...     14.2   14.4   14.6   14.9   15.2   15.5   15.8
# Andorra      143.0  ...    172.0  176.0  178.0  180.0  180.0  178.0  175.0
# Angola        13.6  ...     16.3   16.8   17.5   18.1   18.7   19.4   20.1
#
#               2013   2014   2015
# geo
# Afghanistan   48.6   50.2   51.7
# Albania      107.0  107.0  107.0
# Algeria       16.1   16.4   16.7
# Andorra      172.0  169.0  166.0
# Angola        20.9   21.6   22.3
#
# [5 rows x 24 columns]
# gdp_growth_pc:
#               1992   1993   1994    1995   1996    1997   1998   1999    2000  \
# geo
# Afghanistan -7.950 -13.90 -10.40  20.300   2.66   2.820   2.83  2.710 -1.0500
# Albania     -8.100   8.78   7.44  12.600   8.65 -10.600  12.30  9.580  6.7900
# Algeria     -0.752  -4.44  -3.07   1.710   1.94  -0.558   3.50  1.680  0.9950
# Andorra     -3.740  -5.65  -1.65  -0.114   3.09   8.590   3.30  4.010  0.4010
# Angola      -8.830 -26.40  -1.86  11.600  16.60   2.700  -2.63  0.387 -0.0561
#
#                2001  ...     2006   2007    2008    2009   2010   2011   2012  \
# geo                  ...
# Afghanistan -10.400  ...    1.590  10.80   0.117  17.300  5.170  3.850  11.20
# Albania       6.690  ...    5.270   5.41   6.840   2.910  2.980  2.490   2.28
# Algeria       1.130  ...    0.188   1.85   0.472   0.179  2.060  0.857   1.16
# Andorra      10.000  ...    2.370  -1.70  -5.600  -6.310 -4.780 -4.300  -4.30
# Angola       -0.171  ...   15.000  19.60  10.600  -0.464  0.594  1.030   2.13
#
#              2013   2014  2015
# geo
# Afghanistan  1.13  0.837  2.11
# Albania      1.72  2.610  3.82
# Algeria      1.61  2.180  2.10
# Andorra     -4.30 -4.300 -4.30
# Angola       1.03  2.240  2.46
#
# [5 rows x 24 columns]
# gdp_tot:
#                      1992          1993          1994          1995  \
# geo
# Afghanistan  8.010000e+09  8.010000e+09  8.010000e+09  8.010000e+09
# Albania      4.180000e+09  4.580000e+09  4.970000e+09  5.630000e+09
# Algeria      9.250000e+10  9.060000e+10  8.980000e+10  9.320000e+10
# Andorra      2.020000e+09  2.000000e+09  2.050000e+09  2.100000e+09
# Angola       2.380000e+10  1.810000e+10  1.830000e+10  2.110000e+10
#
#                      1996          1997          1998          1999  \
# geo
# Afghanistan  8.010000e+09  8.010000e+09  8.010000e+09  8.010000e+09
# Albania      6.140000e+09  5.470000e+09  5.970000e+09  6.770000e+09
# Algeria      9.700000e+10  9.810000e+10  1.030000e+11  1.060000e+11
# Andorra      2.200000e+09  2.400000e+09  2.480000e+09  2.580000e+09
# Angola       2.390000e+10  2.570000e+10  2.690000e+10  2.740000e+10
#
#                      2000          2001      ...               2006  \
# geo                                          ...
# Afghanistan  8.010000e+09  8.010000e+09      ...       1.030000e+10
# Albania      7.220000e+09  7.800000e+09      ...       1.010000e+10
# Algeria      1.100000e+11  1.140000e+11      ...       1.450000e+11
# Andorra      2.670000e+09  2.790000e+09      ...       4.030000e+09
# Angola       2.830000e+10  2.950000e+10      ...       5.560000e+10
#
#                      2007          2008          2009          2010  \
# geo
# Afghanistan  1.170000e+10  1.210000e+10  1.470000e+10  1.590000e+10
# Albania      1.070000e+10  1.110000e+10  1.150000e+10  1.190000e+10
# Algeria      1.500000e+11  1.530000e+11  1.560000e+11  1.610000e+11
# Andorra      4.030000e+09  3.680000e+09  3.550000e+09  3.360000e+09
# Angola       6.840000e+10  7.790000e+10  7.980000e+10  8.250000e+10
#
#                      2011          2012          2013          2014  \
# geo
# Afghanistan  1.690000e+10  1.940000e+10  2.010000e+10  2.060000e+10
# Albania      1.220000e+10  1.240000e+10  1.250000e+10  1.280000e+10
# Algeria      1.660000e+11  1.710000e+11  1.760000e+11  1.830000e+11
# Andorra      3.200000e+09  3.150000e+09  3.160000e+09  3.230000e+09
# Angola       8.570000e+10  9.020000e+10  9.630000e+10  1.010000e+11
#
#                      2015
# geo
# Afghanistan  2.090000e+10
# Albania      1.300000e+10
# Algeria      1.900000e+11
# Andorra      3.260000e+09
# Angola       1.040000e+11
#
# [5 rows x 24 columns]
# gdp_pc:
#                 1992     1993     1994     1995     1996     1997     1998  \
# geo
# Afghanistan    365.0    365.0    365.0    365.0    365.0    365.0    365.0
# Albania       11750.40   12412.80   12614.40   12614.40   12614.40   12614.40
# Algeria      411740.00  411740.00  414120.00  414120.00  414120.00  414120.00
# Andorra         207.74     207.74     207.74     197.87     197.87     187.53
# Angola       578750.00  578750.00  585000.00  585000.00  591250.00  591250.00
#
#                  2013      2014      2015
# geo
# Afghanistan  379393.0  379393.0  379393.0
# Albania       12470.4   12355.2   12355.2
# Algeria      414120.0  414120.0  414120.0
# Andorra         188.0     188.0     188.0
# Angola       593750.0  593750.0  593750.0
#
# [5 rows x 24 columns]

# %%
Checking missing values:

# %%
for k, v in df_dict.items():
    print(k + " null values: ")
    print(v.isnull().any(axis=1).sum())
# Out:
# forest_area null values:
# 0
# forest_ratio null values:
# 0
# population_total null values:
# 0
# population_growth null values:
# 0
# population_density null values:
# 0
# gdp_growth_pc null values:
# 0
# gdp_tot null values:
# 0
# gdp_pc null values:
# 0
# agricultural_land_ratio null values:
# 0
# agricultural_gdp_ratio null values:
# 0
# surface_area null values:
# 0
# agro_area null values:
# 0

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
# ### Examining forestation/deforestation trends globally and in the top "forest countries"

# %% [markdown]
# In 'Global forest area: 1992-2015' chart we can see, that the global forest area is shrinking during the period, and there isn't even one year when this trend goes to the opposite direction. The loss is 1242554.2 sq km, this is the total area of France, Germany and the United Kingdom together.

# %%
print("forest lost from 1992 to 2015: ")
forest_sum.loc['2015'] - forest_sum.loc['1992']
# Out:
# forest lost from 1992 to 2015:
# square km   -1242554.2
# dtype: float64

# %%
forest_sum = df_forest.sum().to_frame('sq km')
fig, ax = plt.subplots(1,1, figsize=(12,4))
ax = sns.lineplot(x=forest_sum.index, y="sq km", data=forest_sum)
ax.set_xticklabels(labels=forest_sum.index, rotation=90)
ax.set_title('Global forest area: 1992-2015', fontsize=20)
fig.tight_layout()

# %% [markdown]
# In the next two chart we can examine the histogram of the forest area percent and forest area of the countries of the world. The deforestation isn't so fast that we could see a real difference between 1992 and 2015. The histograms in the 'Histogram of the forest area percent of countries' chart are right skewed, so there is a lot of country with less than 20 percent forest, but there is only a few with more than 80 percent. The 'Histogram of the forest area of countries' shows, that there are some countries with very large forests, but most of the countries have very small total forest area compared to them. This isn't a surprise, there a far more smaller countries than big ones.

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12,4))

n, bins, patches = ax1.hist(df_forest_ratio['1992'].dropna(), alpha=0.5, bins=12)
n, bins, patches = ax1.hist(df_forest_ratio['2015'].dropna(), alpha=0.5, bins=12)

ax1.set_xlabel('forest area percent')
ax1.set_ylabel('country count')
ax1.set_title('Histogram of the forest area percent of countries', fontsize=14)
ax1.legend()

_ = ax2.hist(df_forest['1992'].dropna(), alpha=0.5, bins=50)
_ = ax2.hist(df_forest['2015'].dropna(), alpha=0.5, bins=50)

ax2.set_xlabel('forest area sq km')
ax2.set_ylabel('country count')
ax2.set_title('Histogram of the forest area of countries', fontsize=14)
plt.xticks(rotation='vertical')
ax2.legend()

fig.tight_layout()

# %% [markdown]
# Countries with the largest forest area:

# %%
top_fa = df_forest[['1992', '2015']].sort_values(by=['1992'], ascending=False).head(10)
top_fd = df_forest_ratio[['1992', '2015']].sort_values(by=['1992'], ascending=False).head(10)
top_fa
# Out:
#                        1992       2015
# geo
# Russia            8090000.0  8150000.0
# Brazil            5420000.0  4940000.0
# Canada            3480000.0  3470000.0
# United States     3030000.0  3100000.0
# China             1610000.0  2080000.0
# Congo, Dem. Rep.  1600000.0  1530000.0
# Australia         1290000.0  1250000.0
# Indonesia         1150000.0   910000.0
# Peru               776000.0   740000.0
# Mexico             694000.0   660000.0

# %% [markdown]
# Cumulative forest percent from the largest forest area:

# %%
df_forest = shape_data(df_forest)
forest_2015 = df_forest['2015'].sort_values(ascending=False)
forest_2015 = pd.DataFrame([forest_2015]).transpose()
forest_2015 = forest_2015.rename(columns={"2015": "area"})
world_total = forest_2015.sum()['area']
forest_2015['percen of global'] = (forest_2015 / world_total)*100
forest_2015['cumulative percen of global'] = forest_2015.cumsum()['percen of global']
forest_2015.head()
# Out:
# Column name 'geo' doesn't exist, returned the same dataframe.
#                     area  percen of global  cumulative percen of global
# geo
# Russia         8150000.0         20.467058                    20.467058
# Brazil         4940000.0         12.405800                    32.872857
# Canada         3470000.0          8.714195                    41.587053
# United States  3100000.0          7.785016                    49.372069
# China          2080000.0          5.223495                    54.595563

# %% [markdown]
# In "Top 10 forest countries by area" we can see the countrie with the largest forests. Russia, Brasil, Canada and the US have half of the forests of the world.
# "Top 10 forest countries by percent" shows the real forest countrie, but they are relativelly small.

# %%
n_groups = 10
index = np.arange(n_groups)
bar_width = 0.35

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(14,6))

ax1.bar(index, top_fa['1992'], bar_width, label='1992', tick_label=n_groups) 
ax1.bar(index + bar_width, top_fa['2015'], bar_width, label='2015')
ax1.set_xlabel("country")
ax1.set_ylabel("sq km")
ax1.set_title("Top 10 forest countries by area", fontsize=14)
ax1.set_xticklabels(top_fa.index, rotation=90)
ax1.legend()

ax2.bar(index, top_fd['1992'], bar_width, label='1992', tick_label=n_groups) 
ax2.bar(index + bar_width, top_fd['2015'], bar_width, label='2015')
ax2.set_xlabel("country")
ax2.set_ylabel("percent")
ax2.set_title("Top 10 forest countries by percent", fontsize=14)
ax2.set_xticklabels(top_fd.index, rotation=90)
ax2.legend()
 
fig.tight_layout()

# %%
forestation = (df_forest['2015'] - df_forest['1992']).sort_values(ascending=False)
forestation_extremes = forestation[:5].append(forestation[-5:])
forestation_extremes.to_frame()
# Out:
#                       0
# geo
# China          470000.0
# United States   70000.0
# India           65000.0
# Russia          60000.0
# Vietnam         49600.0
# Myanmar        -93000.0
# Nigeria        -94100.0
# Sudan         -112000.0
# Indonesia     -240000.0
# Brazil        -480000.0

# %%
forestation_pc = (df_forest_ratio['2015'] - df_forest_ratio['1992']).sort_values(ascending=False)
forestation_pc_extremes = forestation_pc[:5].append(forestation_pc[-5:])
forestation_pc_extremes.to_frame()
# Out:
#                        0
# geo
# Bhutan              18.2
# Vietnam             17.4
# Dominican Republic  16.6
# Montenegro          12.0
# Samoa               11.6
# Timor-Leste        -17.4
# Cambodia           -18.1
# Zimbabwe           -19.2
# North Korea        -24.2
# Honduras           -28.6

# %% [markdown]
# In the next chart "Countries with largest forest area change 1992-2015" we can see the countries with largest foret area change. The rainforests of Brasil are smaller and smaller, and the other countrie with the largest forest area lost are fron the tropical zone as well. But fortunatelly there are countries where the forest area increased. A real surprise is China. The new forest in China during the period are close to the loss of Brazil. According to this article [link](https://www.telegraph.co.uk/news/2018/01/05/china-plant-forest-size-ireland-bid-become-world-leader-conservation/) China made very serious efforts to increas its forest area.

# %%
fig, ax1 = plt.subplots(figsize=(12,4))
ax1 = sns.barplot(forestation_extremes.index, forestation_extremes.values, palette='PiYG_r')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=90)
ax1.set_title("Countries with largest forest area change 1992-2015", fontsize=20)
ax1.set_xlabel("country")
ax1.set_ylabel("sq km")
# Out:
# Text(0,0.5,'sq km')

# %% [markdown]
# In "Countries with largest forest percent change 1992-2015" we can see the top countries by forst area percent change.

# %%
fig, ax2 = plt.subplots(figsize=(12,4))
ax2 = sns.barplot(forestation_pc_extremes.index, forestation_pc_extremes.values, palette='PiYG_r')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)
ax2.set_title("Countries with largest forest percent change 1992-2015", fontsize=20)
ax2.set_xlabel("country")
ax2.set_ylabel("sq km")
# Out:
# Text(0,0.5,'sq km')

# %% [markdown]
# ### Deforestation/forestation possible causes

# %% [markdown]
# In this part I will try to find some connection between the changing economic and demographic indicators and the changing of the forest area.

# %%
def country_correlation(row, df_tocorrelate):
    if df_tocorrelate.index.contains(row.name):
        return row.corr(df_tocorrelate.loc[row.name])

# %%
for k, v in df_dict.items():
    print(k + " correlation with forest area: ")
    print(df_forest.apply(axis=1, func=lambda x: country_correlation(x,v)).mean())
    print()
# Out:
# forest_area correlation with forest area:
# 1.0
#
# forest_ratio correlation with forest area:
# 0.9723916187453951
#
# population_total correlation with forest area:
# -0.14647306796708426
#
# population_growth correlation with forest area:
# 0.02585921338233156
#
# population_density correlation with forest area:
# -0.14676544615624423
#
# gdp_growth_pc correlation with forest area:
# -0.06129582651527704
#
# gdp_tot correlation with forest area:
# 0.010633015785713296
#
# gdp_pc correlation with forest area:
# 0.06281643567402515
#
# agricultural_land_ratio correlation with forest area:
# -0.32519512673920686
#
# agricultural_gdp_ratio correlation with forest area:
# -0.08153015076535342
#
# surface_area correlation with forest area:
# 0.03627464311698382
#
# agro_area correlation with forest area:
# -0.3231877494136563

# %%
plt.scatter(df_popt.sum(), df_forest.sum())

# %%
plt.scatter(df_agr_area.sum(), df_forest.sum())

# %%
df_agrtoland.mean().plot()

# %%
df_agr_area.sum().plot()

# %%
plt.scatter(df_gdp_pc.dropna().sum(), df_forest.sum())

# %%
df_global = df_forest.sum().to_frame().rename(columns={0: "global_forest"})
df_global = pd.concat([df_global, df_popt.sum().rename('global_population')], axis=1)
df_global = pd.concat([df_global, df_gdp_tot.sum().rename('global_gdp')], axis=1)
df_global = pd.concat([df_global, df_agr_area.sum().rename('global_agriculture')], axis=1)
df_global
# Out:
#       global_forest  global_population    global_gdp  global_agriculture
# 1992     41062639.9         5466074739  3.873283e+13        4.986132e+07
# 1993     40959522.8         5557523658  3.932121e+13        5.012660e+07
# 1994     40893304.8         5636299128  4.044883e+13        5.029423e+07
# 1995     40815957.7         5715880980  4.168720e+13        5.027745e+07
# 1996     40729508.7         5797131138  4.309879e+13        5.032494e+07
# 1997     40663731.6         5876906562  4.472056e+13        5.045898e+07
# 1998     40583612.6         5958576691  4.584027e+13        5.054531e+07
# 1999     40520623.6         6030165431  4.727628e+13        5.050476e+07
# 2000     40448703.5         6103583205  4.933775e+13        5.056573e+07
# 2001     40407195.9         6185173098  5.027790e+13        5.052514e+07
# 2002     40349779.2         6267936432  5.141982e+13        5.040424e+07
# 2003     40320430.5         6350244668  5.283505e+13        5.029289e+07
# 2004     40281655.8         6423870387  5.515509e+13        5.041213e+07
# 2005     40237717.2         6497743198  5.728270e+13        5.040229e+07
# 2006     40201148.7         6583776500  5.976113e+13        5.026769e+07
# 2007     40138155.3         6671582096  6.234177e+13        5.025218e+07
# 2008     40127487.8         6749991144  6.341257e+13        5.022464e+07
# 2009     40075192.4         6828537945  6.232854e+13        4.982879e+07
# 2010     40043025.0         6920264694  6.501435e+13        4.979074e+07
# 2011     39938837.1         7009780996  6.705124e+13        4.966608e+07
# 2012     39911753.3         7090641804  6.869205e+13        4.975781e+07
# 2013     39880727.4         7174178201  7.051671e+13        4.972243e+07
# 2014     39848631.6         7253856600  7.252097e+13        4.986540e+07
# 2015     39820085.7         7347159203  7.466235e+13        4.957405e+07

# %%
df_gdp_pc['2015'].describe()
# Out:
# count       186.000000
# mean      13335.870968
# std       18619.685086
# min         227.000000
# 25%        1715.000000
# 50%        5505.000000
# 75%       14825.000000
# max      108000.000000
# Name: 2015, dtype: float64

# %%
low_inc = df_gdp_pc[df_gdp_pc['2015'] < df_gdp_pc['2015'].describe()['25%']]
mid_low_inc = df_gdp_pc[(df_gdp_pc['2015'] >= df_gdp_pc['2015'].describe()['25%']) & (df_gdp_pc['2015'] < df_gdp_pc['2015'].describe()['50%'])]
mid_high_inc = df_gdp_pc[(df_gdp_pc['2015'] >= df_gdp_pc['2015'].describe()['50%']) & (df_gdp_pc['2015'] < df_gdp_pc['2015'].describe()['75%'])]
high_inc = df_gdp_pc[df_gdp_pc['2015'] >= df_gdp_pc['2015'].describe()['75%']]
print(df_forest_ratio.apply(axis=1, func=lambda x: country_correlation(x,low_inc)).mean())
print(df_forest_ratio.apply(axis=1, func=lambda x: country_correlation(x,mid_low_inc)).mean())
print(df_forest_ratio.apply(axis=1, func=lambda x: country_correlation(x,mid_high_inc)).mean())
print(df_forest_ratio.apply(axis=1, func=lambda x: country_correlation(x,high_inc)).mean())
# Out:
# -0.24604036973255042
# 0.0048908246128822105
# 0.12288758922125001
# 0.3764617463024202

# %%
plt.scatter(low_inc.dropna().sum(), df_forest_ratio.mean())

# %%
df_forest_ratio.loc[high_inc.dropna().index]
plt.scatter(high_inc.dropna().sum(), df_forest_ratio.loc[high_inc.dropna().index].mean())

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# > **Tip**: Finally, summarize your findings and the results that have been performed. Make sure that you are clear with regards to the limitations of your exploration. If you haven't done any statistical tests, do not imply any statistical conclusions. And make sure you avoid implying causation from correlation!
#
# > **Tip**: Once you are satisfied with your work, you should save a copy of the report in HTML or PDF form via the **File** > **Download as** submenu. Before exporting your report, check over it to make sure that the flow of the report is complete. You should probably remove all of the "Tip" quotes like this one so that the presentation is as tidy as possible. Congratulations!
